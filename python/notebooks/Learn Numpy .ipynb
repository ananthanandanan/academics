# %% [markdown]
# ### Learn Numpy Library

# %%
import numpy as np

num = np.zeros(3) ## create an array of zeroes
print(type(num))
print(type(num[0]))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.float64'>

# %%
# new array
num2 = np.zeros(8)
num2
# Out:
# array([0., 0., 0., 0., 0., 0., 0., 0.])

# %%
num2.shape #so this is 8 row and 0 column
# Out:
# (8,)

# %%
num2.shape = (4,2) # rows=8, col=2
num2
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
# use of linspace()
num3 = np.linspace(5,10,5)
num3
# Out:
# array([ 5.  ,  6.25,  7.5 ,  8.75, 10.  ])

# %%
lists = [2,4,6,7,8]
num4 = np.array(lists) # create a ndarray from lists, but this returns integers
num4
# Out:
# array([2, 4, 6, 7, 8])

# %%
num4.max()
# Out:
# 8

# %%
np.random.seed(0) #reference to create predictable randome no 
z = np.random.randint(10,size=6) #random no from 0-(n-1) and size: array size
z
# Out:
# array([5, 0, 3, 3, 7, 9])

# %%
z[0:3]
# Out:
# array([5, 0, 3])

# %%
from skimage import io
photo = io.imread('ank.jpg')
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape
# Out:
# (1280, 1173, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %%
plt.imshow(photo[::-1])

# %%
plt.imshow(photo[:,::-1])

# %%
plt.imshow(photo[::2,::2]) #half the size of real img

# %%
print(z)
z>5 # gives boolean
# Out:
# [5 0 3 3 7 9]
# array([False, False, False, False,  True,  True])

# %%
z[z>3] #gives array greater than 3
# Out:
# array([5, 7, 9])

# %%
photo_masked = np.where(photo>100,255,0) # -> where(condtn,true,false)

# %%
plt.imshow(photo_masked)

# %%
a_array = np.array([1,2,3,4,5])
b_array = np.array([4,5,6,7,8])

# %%
a_array @ b_array # dot product
# Out:
# 100

# %%
plt.imshow(photo[:,:,0].T)
